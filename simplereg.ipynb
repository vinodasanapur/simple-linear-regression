# %% [markdown]
# #### Simple Liner Regression

# %% [markdown]
# ##### Machine Learning PIPE LINE
# > Data collection
#
# > Data preparation(Data cleaning )
#
# >Split  the data vartically and horizontaly
#
# >Model Building( Chooise related model based on Dataset)
#
# > Evalute the model....

# %% [markdown]
# ### Model bulding
#
# > Import library
#
# > Import (load) dataset
#
# > Data cleaning and analyises
#
# > Split Dataset into traning snd tresting set
#
# > Choise the Model (i,e Algorithm)...
#
# > Train the model (Fit the model)..
#
# > Test the Model..
#
# > Evaluate the Model

# %%
! pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
### Load data set
ds= pd.read_csv(r"SML\Regression\Salary_dataset.csv")

# %%
ds.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
ds
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
ds.duplicated().sum()
# Out:
# np.int64(0)

# %%
### deal with NULL values
ds.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# > Ther are no any duplicated

# %%
ds.drop(columns=['Unnamed: 0'],inplace=True)

# %%
ds
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
ds.shape
# Out:
# (30, 2)

# %%
ds.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
plt.scatter(ds['YearsExperience'],ds['Salary'])
plt.xlabel('Years of Experience')## for x axis
plt.ylabel('Salary')# for y axis
plt.title('Years of Experience vs Salary')## for title  
plt.plot()
# Out:
# []

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x=ds.iloc[:,0]
x
# Out:
# 0      1.2
# 1      1.4
# 2      1.6
# 3      2.1
# 4      2.3
# 5      3.0
# 6      3.1
# 7      3.3
# 8      3.3
# 9      3.8
# 10     4.0
# 11     4.1
# 12     4.1
# 13     4.2
# 14     4.6
# 15     5.0
# 16     5.2
# 17     5.4
# 18     6.0
# 19     6.1
# 20     6.9
# 21     7.2
# 22     8.0
# 23     8.3
# 24     8.8
# 25     9.1
# 26     9.6
# 27     9.7
# 28    10.4
# 29    10.6
# Name: YearsExperience, dtype: float64

# %%
y=ds.iloc[:,1]
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
ds.shape
# Out:
# (30, 2)

# %% [markdown]
# >
#
# >
#
# >import MOdel liner regression

# %%
x_train
# Out:
# 27     9.7
# 11     4.1
# 17     5.4
# 22     8.0
# 5      3.0
# 16     5.2
# 8      3.3
# 14     4.6
# 23     8.3
# 20     6.9
# 1      1.4
# 29    10.6
# 6      3.1
# 4      2.3
# 18     6.0
# 19     6.1
# 9      3.8
# 7      3.3
# 25     9.1
# 3      2.1
# 0      1.2
# 21     7.2
# 15     5.0
# 12     4.1
# Name: YearsExperience, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np
np.array(x_train).reshape(-1,1)
# Out:
# array([[ 9.7],
#        [ 4.1],
#        [ 5.4],
#        [ 8. ],
#        [ 3. ],
#        [ 5.2],
#        [ 3.3],
#        [ 4.6],
#        [ 8.3],
#        [ 6.9],
#        [ 1.4],
#        [10.6],
#        [ 3.1],
#        [ 2.3],
#        [ 6. ],
#        [ 6.1],
#        [ 3.8],
#        [ 3.3],
#        [ 9.1],
#        [ 2.1],
#        [ 1.2],
#        [ 7.2],
#        [ 5. ],
#        [ 4.1]])

# %%
###traning the model
lr=LinearRegression()
lr.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
x_test.values
# Out:
# array([ 1.6, 10.4,  4.2,  4. ,  9.6,  8.8])

# %%
model_predict=lr.predict(x_test.values.reshape(-1,1))

# %%
y_test.values
# Out:
# array([ 37732., 122392.,  57082.,  63219., 116970., 109432.])

# %%
#### evaluating Model 

from sklearn.metrics import mean_absolute_error,root_mean_squared_error,r2_score

mean_absolute_error(y_test,model_predict)
r2_score(y_test,model_predict)
# Out:
# 0.988169515729126

# %%
r2_score(y_test,model_predict)*100
# Out:
# 98.8169515729126
